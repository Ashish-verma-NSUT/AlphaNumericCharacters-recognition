# %%
import os
from pathlib import Path
from keras.preprocessing import image
import matplotlib.pyplot as plt

# %%
p = Path("./datasets/")
dirs = p.glob("*")

image_data = []
labels = []

image_paths = []
label_dict = {"bulbasaur" : 0 , "chalizard": 1, 'pikachu': 2 }
for folder_dir in dirs:
    label = str(folder_dir).split('\\')[1]
    cnt = 0
    print(folder_dir)
    for img_path in folder_dir.glob("*.jpg"):
        img = image.load_img(img_path,target_size = (40,40))
#         print(img.size)
#         img.resize(40,40)
        img_array = image.img_to_array(img)
        
        image_data.append(img_array)
        
        labels.append(label_dict[label])
        cnt+=1
    print(cnt)
# Out:
# datasets\bulbasaur
# 142
# datasets\chalizard
# 143
# datasets\pikachu
# 142

# %%
import numpy as np

# %%
label2pokemon = {0:"bulbasaur", 1:"chalizard", 2:"pikachu" }
x = np.array(image_data)
# x.resize(40,40,3)
y = np.array(labels)
from sklearn.utils import shuffle
x,y = shuffle(x,y,random_state = 2)
x = x/255.0
print(x.shape, y.shape)

# x.reshape(40,40,3)
# Out:
# (427, 40, 40, 3) (427,)

# %%
def drawImg(img, label):
    plt.title(label2pokemon[label])
    plt.imshow(img)
    plt.style.use("seaborn") 
    plt.axis("off")
    plt.show()

# %%
for i in range(10):
#     rand_idx = np.random.randint(400)
    drawImg(x[i],y[i])

# %%
split = int(x.shape[0]*.8)
# print(x.shape, y.shape)
x_ = np.array(x)
y_ = np.array(y)

x = x_[:split, :]
y = y_[:split]

#test set
x_test = x_[split:, :]
y_test = y_[split:]
print(x.shape, y.shape)
print(x_test.shape, y_test.shape)
# Out:
# (341, 40, 40, 3) (341,)
# (86, 40, 40, 3) (86,)

# %%
def softmax(a):
    ea = np.exp(a)
    ans = ea/np.sum(ea, axis = 1, keepdims = True)
    return ans

# %%
class NeuralNetwork:
    def __init__(self, input_size, layers, output_size):
        
        np.random.seed(0)
        
        model = {}
        model['w1'] = np.random.randn(input_size, layers[0])
        model['b1'] = np.zeros((1,layers[0]))
        model['w2'] = np.random.randn(layers[0], layers[1])
        model['b2'] = np.zeros((1,layers[1]))
        model['w3'] = np.random.randn(layers[1], output_size)
        model['b3'] = np.zeros((1,output_size))
        self.model = model 
        
    def forward(self, x):
        w1,w2,w3 = self.model['w1'], self.model['w2'], self.model['w3']
        b1,b2,b3 = self.model['b1'], self.model['b2'], self.model['b3']
        z1 = np.dot(x,w1) + b1
        a1 = np.tanh(z1)
        z2 = np.dot(a1, w2) + b2
        a2 = np.tanh(z2)
        z3 = np.dot(a2, w3) + b3
        y_ = softmax(z3)
        self.activation_outputs = (a1, a2, y_)
        return y_
    
    def backward(self, x, y, learning_rate = 0.001):
        w1,w2,w3 = self.model['w1'], self.model['w2'], self.model['w3']
        b1,b2,b3 = self.model['b1'], self.model['b2'], self.model['b3']
        m = y.shape[0]
        
        a1, a2, y_ = self.activation_outputs
        delta3 = y_ - y
        dw3 = np.dot(a2.T, delta3)
        db3 = np.sum(delta3, axis = 0)
        
        delta2 = (1- np.square(a2))*np.dot(delta3, w3.T)
        dw2 = np.dot(a1.T, delta2)
        db2 = np.sum(delta2, axis = 0)
        
        delta1 = (1-np.square(a1))*np.dot(delta2, w2.T)
        dw1 = np.dot(x.T, delta1)
        db1 = np.sum(delta1 , axis = 0)
        self.model['w1'] -= learning_rate*dw1
        self.model['b1'] -= learning_rate*db1
        self.model['w2'] -= learning_rate*dw2
        self.model['b2'] -= learning_rate*db2
        self.model['w3'] -= learning_rate*dw3
        self.model['b3'] -= learning_rate*db3
    
    def predict(self, x):
        y_out = self.forward(x)
        return np.argmax(y_out, axis = 1)
    
    def summary(self):
        w1,w2,w3 = self.model['w1'], self.model['w2'], self.model['w3']
        
        a1,a2,y_ = self.activation_outputs
        print('w1 ', w1.shape)
        print('a1 ', a1.shape)
        print('w2 ', w2.shape)
        print('a2 ', a2.shape)
        print('w3 ', w3.shape)
        print('y_ ', y_.shape)

# %%
def loss(y_hot, p):
    l = -np.mean(y_hot*np.log(p))
    return l
def one_hot(y,depth):
    m = y.shape[0]
    y_hot = np.zeros((m,depth))
    y_hot[np.arange(m), y] = 1
    return y_hot

# %%
def train(x,y,model,epochs, learning_rate, logs = True):
    training_loss = []
    classes = len(np.unique(y))
    y_hot = one_hot(y,classes)
    
    for i in range(epochs):
        y_ = model.forward(x)
        l = loss(y_hot, y_)
        training_loss.append(l)
        model.backward(x,y_hot,learning_rate)
        if(logs):
            print("Epoch %d loss %.4f"%(i,l))
    return training_loss

# %%
model = NeuralNetwork(input_size = 4800, layers = [40,30], output_size = 3)

# %%
x = x.reshape(x.shape[0],-1)
print(x.shape)
x_test = x_test.reshape(x_test.shape[0],-1)
print(x_test.shape)
# Out:
# (341, 4800)
# (86, 4800)

# %%
l = train(x,y,model,300,0.0002)
# Out:
# Epoch 0 loss 2.1658
# Epoch 1 loss 1.6745
# Epoch 2 loss 1.2407
# Epoch 3 loss 1.0966
# Epoch 4 loss 0.9853
# Epoch 5 loss 0.9057
# Epoch 6 loss 0.8424
# Epoch 7 loss 0.7954
# Epoch 8 loss 0.7356
# Epoch 9 loss 0.6858
# Epoch 10 loss 0.6547
# Epoch 11 loss 0.6379
# Epoch 12 loss 0.6121
# Epoch 13 loss 0.5922
# Epoch 14 loss 0.5847
# Epoch 15 loss 0.5646
# Epoch 16 loss 0.5558
# Epoch 17 loss 0.5435
# Epoch 18 loss 0.5219
# Epoch 19 loss 0.5162
# Epoch 20 loss 0.5001
# Epoch 21 loss 0.4903
# Epoch 22 loss 0.4685
# Epoch 23 loss 0.4806
# Epoch 24 loss 0.4522
# Epoch 25 loss 0.4310
# Epoch 26 loss 0.4333
# Epoch 27 loss 0.4305
# Epoch 28 loss 0.4206
# Epoch 29 loss 0.4280
# Epoch 30 loss 0.4007
# Epoch 31 loss 0.3960
# Epoch 32 loss 0.3934
# Epoch 33 loss 0.3958
# Epoch 34 loss 0.3908
# Epoch 35 loss 0.3766
# Epoch 36 loss 0.3689
# Epoch 37 loss 0.3627
# Epoch 38 loss 0.3601
# Epoch 39 loss 0.3586
# Epoch 40 loss 0.3538
# Epoch 41 loss 0.3469
# Epoch 42 loss 0.3442
# Epoch 43 loss 0.3406
# Epoch 44 loss 0.3401
# Epoch 45 loss 0.3356
# Epoch 46 loss 0.3294
# Epoch 47 loss 0.3238
# Epoch 48 loss 0.3215
# Epoch 49 loss 0.3166
# Epoch 50 loss 0.3143
# Epoch 51 loss 0.3093
# Epoch 52 loss 0.3067
# Epoch 53 loss 0.3018
# Epoch 54 loss 0.2986
# Epoch 55 loss 0.2947
# Epoch 56 loss 0.2922
# Epoch 57 loss 0.2890
# Epoch 58 loss 0.2858
# Epoch 59 loss 0.2830
# Epoch 60 loss 0.2804
# Epoch 61 loss 0.2768
# Epoch 62 loss 0.2748
# Epoch 63 loss 0.2715
# Epoch 64 loss 0.2693
# Epoch 65 loss 0.2664
# Epoch 66 loss 0.2640
# Epoch 67 loss 0.2610
# Epoch 68 loss 0.2589
# Epoch 69 loss 0.2568
# Epoch 70 loss 0.2548
# Epoch 71 loss 0.2522
# Epoch 72 loss 0.2495
# Epoch 73 loss 0.2480
# Epoch 74 loss 0.2457
# Epoch 75 loss 0.2437
# Epoch 76 loss 0.2413
# Epoch 77 loss 0.2390
# Epoch 78 loss 0.2374
# Epoch 79 loss 0.2352
# Epoch 80 loss 0.2330
# Epoch 81 loss 0.2318
# Epoch 82 loss 0.2291
# Epoch 83 loss 0.2276
# Epoch 84 loss 0.2256
# Epoch 85 loss 0.2234
# Epoch 86 loss 0.2217
# Epoch 87 loss 0.2197
# Epoch 88 loss 0.2175
# Epoch 89 loss 0.2159
# Epoch 90 loss 0.2138
# Epoch 91 loss 0.2119
# Epoch 92 loss 0.2107
# Epoch 93 loss 0.2084
# Epoch 94 loss 0.2072
# Epoch 95 loss 0.2058
# Epoch 96 loss 0.2044
# Epoch 97 loss 0.2022
# Epoch 98 loss 0.2009
# Epoch 99 loss 0.1990
# Epoch 100 loss 0.1975
# Epoch 101 loss 0.1955
# Epoch 102 loss 0.1945
# Epoch 103 loss 0.1928
# Epoch 104 loss 0.1914
# Epoch 105 loss 0.1897
# Epoch 106 loss 0.1885
# Epoch 107 loss 0.1870
# Epoch 108 loss 0.1859
# Epoch 109 loss 0.1845
# Epoch 110 loss 0.1834
# Epoch 111 loss 0.1823
# Epoch 112 loss 0.1811
# Epoch 113 loss 0.1801
# Epoch 114 loss 0.1791
# Epoch 115 loss 0.1782
# Epoch 116 loss 0.1771
# Epoch 117 loss 0.1763
# Epoch 118 loss 0.1752
# Epoch 119 loss 0.1745
# Epoch 120 loss 0.1734
# Epoch 121 loss 0.1727
# Epoch 122 loss 0.1716
# Epoch 123 loss 0.1710
# Epoch 124 loss 0.1699
# Epoch 125 loss 0.1693
# Epoch 126 loss 0.1683
# Epoch 127 loss 0.1676
# Epoch 128 loss 0.1667
# Epoch 129 loss 0.1660
# Epoch 130 loss 0.1650
# Epoch 131 loss 0.1643
# Epoch 132 loss 0.1633
# Epoch 133 loss 0.1626
# Epoch 134 loss 0.1617
# Epoch 135 loss 0.1610
# Epoch 136 loss 0.1602
# Epoch 137 loss 0.1595
# Epoch 138 loss 0.1587
# Epoch 139 loss 0.1581
# Epoch 140 loss 0.1573
# Epoch 141 loss 0.1567
# Epoch 142 loss 0.1560
# Epoch 143 loss 0.1554
# Epoch 144 loss 0.1547
# Epoch 145 loss 0.1541
# Epoch 146 loss 0.1534
# Epoch 147 loss 0.1529
# Epoch 148 loss 0.1522
# Epoch 149 loss 0.1517
# Epoch 150 loss 0.1511
# Epoch 151 loss 0.1506
# Epoch 152 loss 0.1499
# Epoch 153 loss 0.1494
# Epoch 154 loss 0.1488
# Epoch 155 loss 0.1484
# Epoch 156 loss 0.1478
# Epoch 157 loss 0.1473
# Epoch 158 loss 0.1467
# Epoch 159 loss 0.1463
# Epoch 160 loss 0.1457
# Epoch 161 loss 0.1453
# Epoch 162 loss 0.1447
# Epoch 163 loss 0.1443
# Epoch 164 loss 0.1437
# Epoch 165 loss 0.1432
# Epoch 166 loss 0.1426
# Epoch 167 loss 0.1422
# Epoch 168 loss 0.1416
# Epoch 169 loss 0.1413
# Epoch 170 loss 0.1407
# Epoch 171 loss 0.1404
# Epoch 172 loss 0.1397
# Epoch 173 loss 0.1393
# Epoch 174 loss 0.1388
# Epoch 175 loss 0.1386
# Epoch 176 loss 0.1379
# Epoch 177 loss 0.1377
# Epoch 178 loss 0.1372
# Epoch 179 loss 0.1372
# Epoch 180 loss 0.1363
# Epoch 181 loss 0.1362
# Epoch 182 loss 0.1360
# Epoch 183 loss 0.1353
# Epoch 184 loss 0.1348
# Epoch 185 loss 0.1348
# Epoch 186 loss 0.1340
# Epoch 187 loss 0.1338
# Epoch 188 loss 0.1336
# Epoch 189 loss 0.1328
# Epoch 190 loss 0.1327
# Epoch 191 loss 0.1324
# Epoch 192 loss 0.1315
# Epoch 193 loss 0.1316
# Epoch 194 loss 0.1312
# Epoch 195 loss 0.1302
# Epoch 196 loss 0.1300
# Epoch 197 loss 0.1301
# Epoch 198 loss 0.1291
# Epoch 199 loss 0.1292
# Epoch 200 loss 0.1289
# Epoch 201 loss 0.1278
# Epoch 202 loss 0.1278
# Epoch 203 loss 0.1277
# Epoch 204 loss 0.1265
# Epoch 205 loss 0.1266
# Epoch 206 loss 0.1261
# Epoch 207 loss 0.1252
# Epoch 208 loss 0.1254
# Epoch 209 loss 0.1244
# Epoch 210 loss 0.1246
# Epoch 211 loss 0.1240
# Epoch 212 loss 0.1242
# Epoch 213 loss 0.1231
# Epoch 214 loss 0.1233
# Epoch 215 loss 0.1231
# Epoch 216 loss 0.1220
# Epoch 217 loss 0.1217
# Epoch 218 loss 0.1220
# Epoch 219 loss 0.1216
# Epoch 220 loss 0.1208
# Epoch 221 loss 0.1210
# Epoch 222 loss 0.1196
# Epoch 223 loss 0.1193
# Epoch 224 loss 0.1194
# Epoch 225 loss 0.1184
# Epoch 226 loss 0.1188
# Epoch 227 loss 0.1179
# Epoch 228 loss 0.1169
# Epoch 229 loss 0.1172
# Epoch 230 loss 0.1176
# Epoch 231 loss 0.1154
# Epoch 232 loss 0.1152
# Epoch 233 loss 0.1152
# Epoch 234 loss 0.1147
# Epoch 235 loss 0.1149
# Epoch 236 loss 0.1139
# Epoch 237 loss 0.1145
# Epoch 238 loss 0.1133
# Epoch 239 loss 0.1138
# Epoch 240 loss 0.1131
# Epoch 241 loss 0.1129
# Epoch 242 loss 0.1126
# Epoch 243 loss 0.1121
# Epoch 244 loss 0.1120
# Epoch 245 loss 0.1111
# Epoch 246 loss 0.1115
# Epoch 247 loss 0.1102
# Epoch 248 loss 0.1101
# Epoch 249 loss 0.1107
# Epoch 250 loss 0.1096
# Epoch 251 loss 0.1101
# Epoch 252 loss 0.1093
# Epoch 253 loss 0.1098
# Epoch 254 loss 0.1085
# Epoch 255 loss 0.1083
# Epoch 256 loss 0.1085
# Epoch 257 loss 0.1089
# Epoch 258 loss 0.1075
# Epoch 259 loss 0.1074
# Epoch 260 loss 0.1075
# Epoch 261 loss 0.1080
# Epoch 262 loss 0.1066
# Epoch 263 loss 0.1064
# Epoch 264 loss 0.1062
# Epoch 265 loss 0.1060
# Epoch 266 loss 0.1058
# Epoch 267 loss 0.1062
# Epoch 268 loss 0.1062
# Epoch 269 loss 0.1057
# Epoch 270 loss 0.1059
# Epoch 271 loss 0.1051
# Epoch 272 loss 0.1055
# Epoch 273 loss 0.1045
# Epoch 274 loss 0.1050
# Epoch 275 loss 0.1043
# Epoch 276 loss 0.1047
# Epoch 277 loss 0.1037
# Epoch 278 loss 0.1042
# Epoch 279 loss 0.1036
# Epoch 280 loss 0.1039
# Epoch 281 loss 0.1030
# Epoch 282 loss 0.1035
# Epoch 283 loss 0.1027
# Epoch 284 loss 0.1031
# Epoch 285 loss 0.1022
# Epoch 286 loss 0.1027
# Epoch 287 loss 0.1020
# Epoch 288 loss 0.1024
# Epoch 289 loss 0.1015
# Epoch 290 loss 0.1019
# Epoch 291 loss 0.1012
# Epoch 292 loss 0.1016
# Epoch 293 loss 0.1007
# Epoch 294 loss 0.1012
# Epoch 295 loss 0.1005
# Epoch 296 loss 0.1009
# Epoch 297 loss 0.1000
# Epoch 298 loss 0.1005
# Epoch 299 loss 0.0998

# %%
from matplotlib import pyplot as plt
plt.style.use("dark_background")
plt.title("Training loss")
plt.plot(l)
plt.show()

# %%
outputs = model.predict(x)
training_accuracy = np.sum(outputs == y)/y.shape[0]
print("training Accuracy %.4f"% training_accuracy)
outputs_test = model.predict(x_test)
testing_accuracy = np.sum(outputs_test == y_test)/y_test.shape[0]
print("testing accuracy %.4f"% testing_accuracy)
# Out:
# training Accuracy 0.8563
# testing accuracy 0.6860

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(outputs_test,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83        37
#            1       0.57      0.48      0.52        25
#            2       0.59      0.67      0.63        24
#
#     accuracy                           0.69        86
#    macro avg       0.66      0.66      0.66        86
# weighted avg       0.68      0.69      0.68        86

# %%
for i in range(y.shape[0]):
    if y[i]==outputs[i]:
        drawImg(x[i].reshape(40,40,3),y[i])
        print("prediction %d %s"%(i,label2pokemon[outputs[i]]))
# Out:
# prediction 0 bulbasaur
# prediction 1 pikachu
# prediction 2 chalizard
# prediction 3 chalizard
# prediction 4 bulbasaur
# prediction 5 pikachu
# prediction 6 chalizard
# prediction 7 chalizard
# prediction 8 bulbasaur
# prediction 9 pikachu
# prediction 10 bulbasaur
# prediction 12 chalizard
# prediction 13 chalizard
# prediction 14 pikachu
# prediction 15 chalizard
# prediction 16 bulbasaur
# prediction 17 pikachu
# prediction 19 pikachu
# prediction 20 pikachu
# prediction 21 chalizard
# prediction 22 pikachu
# prediction 23 bulbasaur
# prediction 24 bulbasaur
# prediction 25 chalizard
# prediction 26 chalizard
# prediction 27 pikachu
# prediction 28 chalizard
# prediction 29 pikachu
# prediction 30 bulbasaur
# prediction 33 pikachu
# prediction 34 bulbasaur
# prediction 35 bulbasaur
# prediction 36 chalizard
# prediction 37 pikachu
# prediction 38 pikachu
# prediction 39 pikachu
# prediction 40 bulbasaur
# prediction 41 bulbasaur
# prediction 42 chalizard
# prediction 43 chalizard
# prediction 44 pikachu
# prediction 45 pikachu
# prediction 46 chalizard
# prediction 47 bulbasaur
# prediction 48 bulbasaur
# prediction 49 bulbasaur
# prediction 50 bulbasaur
# prediction 52 pikachu
# prediction 53 bulbasaur
# prediction 54 chalizard
# prediction 55 bulbasaur
# prediction 56 pikachu
# prediction 57 pikachu
# prediction 58 chalizard
# prediction 59 chalizard
# prediction 61 pikachu
# prediction 62 bulbasaur
# prediction 63 chalizard
# prediction 64 pikachu
# prediction 65 bulbasaur
# prediction 66 chalizard
# prediction 67 bulbasaur
# prediction 69 pikachu
# prediction 70 pikachu
# prediction 71 chalizard
# prediction 73 pikachu
# prediction 75 pikachu
# prediction 76 chalizard
# prediction 77 bulbasaur
# prediction 78 bulbasaur
# prediction 79 chalizard
# prediction 80 chalizard
# prediction 81 chalizard
# prediction 82 chalizard
# prediction 83 bulbasaur
# prediction 85 bulbasaur
# prediction 86 pikachu
# prediction 87 chalizard
# prediction 88 chalizard
# prediction 89 bulbasaur
# prediction 90 bulbasaur
# prediction 93 chalizard
# prediction 94 pikachu
# prediction 95 pikachu
# prediction 96 chalizard
# prediction 97 chalizard
# prediction 98 pikachu
# prediction 99 bulbasaur
# prediction 100 pikachu
# prediction 101 bulbasaur
# prediction 103 chalizard
# prediction 105 pikachu
# prediction 106 chalizard
# prediction 107 bulbasaur
# prediction 108 chalizard
# prediction 110 chalizard
# prediction 111 bulbasaur
# prediction 113 chalizard
# prediction 114 chalizard
# prediction 115 pikachu
# prediction 117 chalizard
# prediction 118 bulbasaur
# prediction 119 bulbasaur
# prediction 120 chalizard
# prediction 121 pikachu
# prediction 122 bulbasaur
# prediction 123 chalizard
# prediction 124 bulbasaur
# prediction 125 chalizard
# prediction 126 pikachu
# prediction 127 pikachu
# prediction 128 pikachu
# prediction 129 chalizard
# prediction 130 chalizard
# prediction 131 chalizard
# prediction 132 bulbasaur
# prediction 133 pikachu
# prediction 134 chalizard
# prediction 135 pikachu
# prediction 136 bulbasaur
# prediction 137 chalizard
# prediction 138 chalizard
# prediction 139 pikachu
# prediction 140 bulbasaur
# prediction 141 chalizard
# prediction 142 chalizard
# prediction 143 bulbasaur
# prediction 144 chalizard
# prediction 145 bulbasaur
# prediction 146 chalizard
# prediction 147 pikachu
# prediction 148 bulbasaur
# prediction 150 bulbasaur
# prediction 151 chalizard
# prediction 153 pikachu
# prediction 154 chalizard
# prediction 155 pikachu
# prediction 156 chalizard
# prediction 157 bulbasaur
# prediction 158 bulbasaur
# prediction 160 pikachu
# prediction 161 chalizard
# prediction 162 chalizard
# prediction 163 bulbasaur
# prediction 164 chalizard
# prediction 165 pikachu
# prediction 166 chalizard
# prediction 167 bulbasaur
# prediction 169 chalizard
# prediction 171 chalizard
# prediction 172 bulbasaur
# prediction 173 bulbasaur
# prediction 174 chalizard
# prediction 175 bulbasaur
# prediction 176 pikachu
# prediction 177 pikachu
# prediction 178 pikachu
# prediction 179 bulbasaur
# prediction 180 chalizard
# prediction 181 bulbasaur
# prediction 182 bulbasaur
# prediction 183 pikachu
# prediction 184 pikachu
# prediction 185 pikachu
# prediction 186 bulbasaur
# prediction 189 chalizard
# prediction 190 bulbasaur
# prediction 191 chalizard
# prediction 192 chalizard
# prediction 193 bulbasaur
# prediction 194 bulbasaur
# prediction 195 chalizard
# prediction 196 pikachu
# prediction 197 bulbasaur
# prediction 198 bulbasaur
# prediction 200 chalizard
# prediction 202 bulbasaur
# prediction 203 bulbasaur
# prediction 206 chalizard
# prediction 207 pikachu
# prediction 210 bulbasaur
# prediction 211 pikachu
# prediction 212 bulbasaur
# prediction 213 pikachu
# prediction 214 chalizard
# prediction 215 pikachu
# prediction 216 bulbasaur
# prediction 217 pikachu
# prediction 218 bulbasaur
# prediction 219 pikachu
# prediction 220 pikachu
# prediction 221 bulbasaur
# prediction 222 chalizard
# prediction 224 bulbasaur
# prediction 226 chalizard
# prediction 227 bulbasaur
# prediction 228 pikachu
# prediction 229 pikachu
# prediction 230 pikachu
# prediction 232 chalizard
# prediction 234 bulbasaur
# prediction 235 pikachu
# prediction 236 chalizard
# prediction 237 pikachu
# prediction 238 bulbasaur
# prediction 241 chalizard
# prediction 242 pikachu
# prediction 243 bulbasaur
# prediction 244 bulbasaur
# prediction 245 bulbasaur
# prediction 246 chalizard
# prediction 247 bulbasaur
# prediction 248 bulbasaur
# prediction 249 bulbasaur
# prediction 250 chalizard
# prediction 252 bulbasaur
# prediction 253 chalizard
# prediction 254 bulbasaur
# prediction 255 bulbasaur
# prediction 256 pikachu
# prediction 257 bulbasaur
# prediction 258 pikachu
# prediction 259 pikachu
# prediction 260 chalizard
# prediction 261 chalizard
# prediction 262 chalizard
# prediction 263 pikachu
# prediction 264 chalizard
# prediction 265 pikachu
# prediction 266 bulbasaur
# prediction 267 bulbasaur
# prediction 269 pikachu
# prediction 270 pikachu
# prediction 272 bulbasaur
# prediction 273 chalizard
# prediction 274 bulbasaur
# prediction 275 pikachu
# prediction 277 pikachu
# prediction 278 chalizard
# prediction 281 pikachu
# prediction 282 pikachu
# prediction 283 bulbasaur
# prediction 284 bulbasaur
# prediction 285 pikachu
# prediction 286 pikachu
# prediction 287 pikachu
# prediction 288 chalizard
# prediction 289 chalizard
# prediction 290 bulbasaur
# prediction 291 pikachu
# prediction 292 chalizard
# prediction 293 pikachu
# prediction 294 pikachu
# prediction 295 pikachu
# prediction 296 bulbasaur
# prediction 297 bulbasaur
# prediction 298 pikachu
# prediction 300 pikachu
# prediction 301 pikachu
# prediction 302 chalizard
# prediction 303 pikachu
# prediction 304 chalizard
# prediction 305 bulbasaur
# prediction 306 chalizard
# prediction 307 pikachu
# prediction 308 bulbasaur
# prediction 309 pikachu
# prediction 312 bulbasaur
# prediction 313 chalizard
# prediction 314 bulbasaur
# prediction 315 bulbasaur
# prediction 316 bulbasaur
# prediction 318 chalizard
# prediction 319 chalizard
# prediction 320 chalizard
# prediction 321 chalizard
# prediction 322 chalizard
# prediction 323 pikachu
# prediction 324 pikachu
# prediction 325 pikachu
# prediction 326 chalizard
# prediction 327 chalizard
# prediction 330 chalizard
# prediction 331 pikachu
# prediction 332 chalizard
# prediction 333 pikachu
# prediction 334 chalizard
# prediction 335 bulbasaur
# prediction 336 pikachu
# prediction 338 chalizard
# prediction 339 pikachu
# prediction 340 chalizard
